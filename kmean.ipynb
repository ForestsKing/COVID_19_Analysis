# %%
import joblib
from time import time
from tqdm import tqdm

import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score

# %%
language = ['ch', 'en']
files = ['2020',
         '202001', '202002', '202003', '202004', '202005', '202006', 
         '202007', '202008', '202009', '202010', '202011', '202012']

# %% [markdown]
# ### 文档聚类

# %%
TRAIN = True
NC = [10, 12, 14, 16, 18]

# %%
for file in files:
    for lang in language:
        print(file+' | '+lang+':')
        df = pd.read_csv('./result/lda/'+file+'/'+lang+'/doc2theme.csv')
        x = df.iloc[:, :-2].values
        
        if TRAIN:
            score = -np.inf
            for n_cluster in NC:
                s = time()
                kmean = KMeans(n_clusters=n_cluster, random_state=42)
                kmean.fit(x)
                pred = kmean.predict(x)
                sc = calinski_harabasz_score(x, pred)
                e = time()

                if sc > score:
                    score = sc
                    print('Cost: {0:.4f} | Nclusters: {1} | Score: {2:.4f} | save model...'.format(e-s, n_cluster, sc))
                    joblib.dump(kmean, './result/kmean/'+file+'/'+lang+'/kmean.pkl') 
                    
                else:
                    print('Cost: {0:.4f} | Nclusters: {1} | Score: {2:.4f} |'.format(e-s, n_cluster, sc))
        
        kmean = joblib.load('./result/kmean/'+file+'/'+lang+'/kmean.pkl')
        pred = kmean.predict(x)
        df = pd.read_csv('./result/lda/'+file+'/'+lang+'/doc2theme_hard.csv')
        df['category'] = pred
        df.to_csv('./result/kmean/'+file+'/'+lang+'/doc2cate.csv', index=False)
        
        theme2word = pd.read_csv('./result/lda/'+file+'/'+lang+'/theme2word.csv')
        A = df.groupby('category').sum().iloc[:, :20].values.astype('float64')
        CHI = np.zeros_like(A)
        for i in range(len(A)):
            for j in range(len(A[0, :])):
                a = A[i, j]
                b = np.sum(A[i, :]) - a
                c = np.sum(A[:, j]) - a
                d = np.sum(A) - a - b - c
                if min(a+c, b+d, a+b, c+d)==0:
                    CHI[i ,j] = 0
                else:
                    CHI[i, j] = ((a*d-b*c)**2) / ((a+c)*(b+d)*(a+b)*(c+d))
                
        cate2theme = CHI
        
        mask = cate2theme.argsort()[:, -2:]
        for i in range(len(cate2theme)):
            for j in range(len(cate2theme[0, :])):
                if j in mask[i]:
                    cate2theme[i, j] = cate2theme[i, j]
                else:
                    cate2theme[i, j] = 0
        
        weight = np.matmul(cate2theme, theme2word.values)
        df_c2w = pd.DataFrame(weight, columns=theme2word.columns.values)
        df_c2w.to_csv('./result/kmean/'+file+'/'+lang+'/cate2word.csv', index=False)
                           
        print('==================================================================')
# Out:
# 2020 | ch:
# Cost: 4.7959 | Nclusters: 10 | Score: 81933.9836 | save model...
# Cost: 5.0863 | Nclusters: 12 | Score: 94487.7619 | save model...
# Cost: 5.8271 | Nclusters: 14 | Score: 115922.4820 | save model...
# Cost: 5.8668 | Nclusters: 16 | Score: 141660.2615 | save model...
# Cost: 6.5880 | Nclusters: 18 | Score: 189528.1772 | save model...
# ==================================================================
# 2020 | en:
# Cost: 4.8732 | Nclusters: 10 | Score: 36017.8920 | save model...
# Cost: 5.2088 | Nclusters: 12 | Score: 38311.7473 | save model...
# Cost: 5.2688 | Nclusters: 14 | Score: 44418.2602 | save model...
# Cost: 5.5671 | Nclusters: 16 | Score: 51831.2809 | save model...
# Cost: 6.3743 | Nclusters: 18 | Score: 58350.4993 | save model...
# ==================================================================
# 202001 | ch:
# Cost: 0.9536 | Nclusters: 10 | Score: 7617.8809 | save model...
# Cost: 3.0934 | Nclusters: 12 | Score: 9382.7292 | save model...
# Cost: 1.6599 | Nclusters: 14 | Score: 10446.6114 | save model...
# Cost: 1.4179 | Nclusters: 16 | Score: 14267.4564 | save model...
# Cost: 2.4620 | Nclusters: 18 | Score: 18867.1608 | save model...
# ==================================================================
# 202001 | en:
# Cost: 0.0942 | Nclusters: 10 | Score: 12.1815 | save model...
# Cost: 0.0613 | Nclusters: 12 | Score: 15.3758 | save model...
# Cost: 0.0117 | Nclusters: 14 | Score: 21.3167 | save model...
# Cost: 0.0156 | Nclusters: 16 | Score: 29.4376 | save model...
# Cost: 0.0167 | Nclusters: 18 | Score: 60.9110 | save model...
# ==================================================================
# 202002 | ch:
# Cost: 3.3345 | Nclusters: 10 | Score: 14220.8269 | save model...
# Cost: 4.0978 | Nclusters: 12 | Score: 16900.0508 | save model...
# Cost: 3.9301 | Nclusters: 14 | Score: 20073.9540 | save model...
# Cost: 4.4218 | Nclusters: 16 | Score: 25465.4351 | save model...
# Cost: 4.4449 | Nclusters: 18 | Score: 34951.9401 | save model...
# ==================================================================
# 202002 | en:
# Cost: 0.1596 | Nclusters: 10 | Score: 23.3551 | save model...
# Cost: 0.0142 | Nclusters: 12 | Score: 31.0449 | save model...
# Cost: 0.0133 | Nclusters: 14 | Score: 40.6978 | save model...
# Cost: 0.0163 | Nclusters: 16 | Score: 58.2241 | save model...
# Cost: 0.0137 | Nclusters: 18 | Score: 120.4450 | save model...
# ==================================================================
# 202003 | ch:
# Cost: 3.6704 | Nclusters: 10 | Score: 10870.1712 | save model...
# Cost: 3.7850 | Nclusters: 12 | Score: 12876.9167 | save model...
# Cost: 3.8598 | Nclusters: 14 | Score: 14781.2669 | save model...
# Cost: 3.9988 | Nclusters: 16 | Score: 17735.0269 | save model...
# Cost: 3.1683 | Nclusters: 18 | Score: 23225.9268 | save model...
# ==================================================================
# 202003 | en:
# Cost: 1.8674 | Nclusters: 10 | Score: 2695.4262 | save model...
# Cost: 2.9659 | Nclusters: 12 | Score: 2920.9342 | save model...
# Cost: 1.6089 | Nclusters: 14 | Score: 3392.9045 | save model...
# Cost: 1.1860 | Nclusters: 16 | Score: 4052.5569 | save model...
# Cost: 1.6738 | Nclusters: 18 | Score: 5004.6220 | save model...
# ==================================================================
# 202004 | ch:
# Cost: 1.8844 | Nclusters: 10 | Score: 17866.1082 | save model...
# Cost: 1.5698 | Nclusters: 12 | Score: 20144.0865 | save model...
# Cost: 2.0978 | Nclusters: 14 | Score: 23493.9343 | save model...
# Cost: 2.1503 | Nclusters: 16 | Score: 28183.9956 | save model...
# Cost: 2.5359 | Nclusters: 18 | Score: 35609.7090 | save model...
# ==================================================================
# 202004 | en:
# Cost: 2.1850 | Nclusters: 10 | Score: 5121.9040 | save model...
# Cost: 2.0717 | Nclusters: 12 | Score: 5829.5299 | save model...
# Cost: 1.8437 | Nclusters: 14 | Score: 6592.2235 | save model...
# Cost: 2.3609 | Nclusters: 16 | Score: 7762.0610 | save model...
# Cost: 2.4013 | Nclusters: 18 | Score: 9091.8116 | save model...
# ==================================================================
# 202005 | ch:
# Cost: 1.0019 | Nclusters: 10 | Score: 5352.4289 | save model...
# Cost: 1.8997 | Nclusters: 12 | Score: 5803.9525 | save model...
# Cost: 1.0272 | Nclusters: 14 | Score: 7090.0927 | save model...
# Cost: 1.0825 | Nclusters: 16 | Score: 8375.7932 | save model...
# Cost: 1.6032 | Nclusters: 18 | Score: 11680.6033 | save model...
# ==================================================================
# 202005 | en:
# Cost: 2.6439 | Nclusters: 10 | Score: 5122.3412 | save model...
# Cost: 2.0168 | Nclusters: 12 | Score: 6014.1783 | save model...
# Cost: 2.3727 | Nclusters: 14 | Score: 6537.3199 | save model...
# Cost: 2.4597 | Nclusters: 16 | Score: 7587.1509 | save model...
# Cost: 2.9463 | Nclusters: 18 | Score: 9124.7038 | save model...
# ==================================================================
# 202006 | ch:
# Cost: 0.7145 | Nclusters: 10 | Score: 3107.4926 | save model...
# Cost: 0.7672 | Nclusters: 12 | Score: 3663.8252 | save model...
# Cost: 1.7956 | Nclusters: 14 | Score: 4525.2222 | save model...
# Cost: 1.0453 | Nclusters: 16 | Score: 5650.5318 | save model...
# Cost: 1.2150 | Nclusters: 18 | Score: 7403.6557 | save model...
# ==================================================================
# 202006 | en:
# Cost: 1.9352 | Nclusters: 10 | Score: 4063.0247 | save model...
# Cost: 2.2448 | Nclusters: 12 | Score: 4488.4863 | save model...
# Cost: 1.6402 | Nclusters: 14 | Score: 5207.4164 | save model...
# Cost: 1.7065 | Nclusters: 16 | Score: 6035.8143 | save model...
# Cost: 1.9536 | Nclusters: 18 | Score: 7131.4081 | save model...
# ==================================================================
# 202007 | ch:
# Cost: 0.6848 | Nclusters: 10 | Score: 3257.9966 | save model...
# Cost: 0.8992 | Nclusters: 12 | Score: 3871.6184 | save model...
# Cost: 1.4781 | Nclusters: 14 | Score: 4711.1568 | save model...
# Cost: 0.7819 | Nclusters: 16 | Score: 5717.3815 | save model...
# Cost: 0.8749 | Nclusters: 18 | Score: 7883.1607 | save model...
# ==================================================================
# 202007 | en:
# Cost: 1.8390 | Nclusters: 10 | Score: 4231.1389 | save model...
# Cost: 1.6764 | Nclusters: 12 | Score: 4807.0408 | save model...
# Cost: 1.7172 | Nclusters: 14 | Score: 5458.5077 | save model...
# Cost: 1.8763 | Nclusters: 16 | Score: 6251.2673 | save model...
# Cost: 1.9661 | Nclusters: 18 | Score: 7505.1694 | save model...
# ==================================================================
# 202008 | ch:
# Cost: 0.4036 | Nclusters: 10 | Score: 2497.2756 | save model...
# Cost: 0.4571 | Nclusters: 12 | Score: 2941.7983 | save model...
# Cost: 0.4995 | Nclusters: 14 | Score: 3394.7375 | save model...
# Cost: 1.5936 | Nclusters: 16 | Score: 4233.6124 | save model...
# Cost: 0.8380 | Nclusters: 18 | Score: 5619.4029 | save model...
# ==================================================================
# 202008 | en:
# Cost: 1.0167 | Nclusters: 10 | Score: 3361.1096 | save model...
# Cost: 1.9790 | Nclusters: 12 | Score: 3748.6481 | save model...
# Cost: 1.5513 | Nclusters: 14 | Score: 4317.8887 | save model...
# Cost: 1.6574 | Nclusters: 16 | Score: 5104.6442 | save model...
# Cost: 1.7453 | Nclusters: 18 | Score: 6077.5201 | save model...
# ==================================================================
# 202009 | ch:
# Cost: 0.5543 | Nclusters: 10 | Score: 4014.4090 | save model...
# Cost: 1.5798 | Nclusters: 12 | Score: 4761.1715 | save model...
# Cost: 0.7653 | Nclusters: 14 | Score: 5563.5963 | save model...
# Cost: 0.8308 | Nclusters: 16 | Score: 7475.6873 | save model...
# Cost: 0.9942 | Nclusters: 18 | Score: 10016.0855 | save model...
# ==================================================================
# 202009 | en:
# Cost: 0.9740 | Nclusters: 10 | Score: 2949.0500 | save model...
# Cost: 2.0547 | Nclusters: 12 | Score: 3111.4333 | save model...
# Cost: 1.0836 | Nclusters: 14 | Score: 3579.7436 | save model...
# Cost: 1.0552 | Nclusters: 16 | Score: 4419.6297 | save model...
# Cost: 1.6726 | Nclusters: 18 | Score: 5277.0839 | save model...
# ==================================================================
# 202010 | ch:
# Cost: 0.6116 | Nclusters: 10 | Score: 2279.5717 | save model...
# Cost: 0.4233 | Nclusters: 12 | Score: 2859.2064 | save model...
# Cost: 1.4085 | Nclusters: 14 | Score: 3432.8750 | save model...
# Cost: 0.6117 | Nclusters: 16 | Score: 4343.2699 | save model...
# Cost: 0.7759 | Nclusters: 18 | Score: 5707.5787 | save model...
# ==================================================================
# 202010 | en:
# Cost: 1.0524 | Nclusters: 10 | Score: 3346.0932 | save model...
# Cost: 1.6843 | Nclusters: 12 | Score: 3935.6720 | save model...
# Cost: 1.3950 | Nclusters: 14 | Score: 4331.5119 | save model...
# Cost: 1.4094 | Nclusters: 16 | Score: 5055.2735 | save model...
# Cost: 2.0807 | Nclusters: 18 | Score: 6068.3016 | save model...
# ==================================================================
# 202011 | ch:
# Cost: 0.5616 | Nclusters: 10 | Score: 2354.4052 | save model...
# Cost: 0.8823 | Nclusters: 12 | Score: 2613.0039 | save model...
# Cost: 1.4855 | Nclusters: 14 | Score: 3367.8121 | save model...
# Cost: 0.7064 | Nclusters: 16 | Score: 4057.7034 | save model...
# Cost: 0.7811 | Nclusters: 18 | Score: 5254.7028 | save model...
# ==================================================================
# 202011 | en:
# Cost: 0.7999 | Nclusters: 10 | Score: 2903.7632 | save model...
# Cost: 0.8175 | Nclusters: 12 | Score: 3323.7141 | save model...
# Cost: 1.6665 | Nclusters: 14 | Score: 3834.3523 | save model...
# Cost: 1.2330 | Nclusters: 16 | Score: 4414.7946 | save model...
# Cost: 1.8436 | Nclusters: 18 | Score: 5461.3794 | save model...
# ==================================================================
# 202012 | ch:
# Cost: 0.8174 | Nclusters: 10 | Score: 4122.0959 | save model...
# Cost: 1.6296 | Nclusters: 12 | Score: 4456.8596 | save model...
# Cost: 0.8115 | Nclusters: 14 | Score: 5695.9367 | save model...
# Cost: 0.8708 | Nclusters: 16 | Score: 7222.5278 | save model...
# Cost: 1.3280 | Nclusters: 18 | Score: 9926.8728 | save model...
# ==================================================================
# 202012 | en:
# Cost: 1.4758 | Nclusters: 10 | Score: 3049.9237 | save model...
# Cost: 2.0908 | Nclusters: 12 | Score: 3340.3969 | save model...
# Cost: 1.3418 | Nclusters: 14 | Score: 3812.5287 | save model...
# Cost: 1.2183 | Nclusters: 16 | Score: 4495.7927 | save model...
# Cost: 1.5107 | Nclusters: 18 | Score: 5632.4277 | save model...
# ==================================================================
